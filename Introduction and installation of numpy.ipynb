# %% [markdown]
# ## Numpy - Numeric Python

# %% [raw]
# - def : Numpy is a open source python library for numeric operations.
# - Interview Question : What is main difference between python list and numpy array.
# - 1. Numpy array is more faster than python list.
# - 2. Numpy array takes lower memory then the python list to store elements.
# - 3. list are heterogenious but numpy array are homogenious
#
# - Why numpy array are faster?
# - 1. Numpy array store the elements in continous memory location.
# - 2. Numpy array approximately 50x faster than python list.
# - 3. Numpy array are good at working with multiprocessors
#
# - Numpy is designed using c,c++ and python

# %%
# Important Operation of Numpy:

# 1. Installing, upgrading, importing and version check 
# 2. Create numpy Arrays( 1D, 2D, 3D..)
# 3. Special type of numpy array
# 4. Array Shape, reshape and transpose
# 5. Array Size, DataType, Datatype conversion
# 6. Indexing, Slicing and modifications
# 7. Mathematical & Statistical Operations
# 8. Concatination, stacking and splitting numpy array

# %% [markdown]
# ### 1. Installing, upgrading, importing and version check

# %%
# to install numpy we use
# pip install numpy

# to upgrade the existing numpy
# pip install -U numpy

# %%
# Importing numpy library
import numpy as np

# %%
# checking current version of numpy

np.__version__
# Out:
# '1.24.4'
