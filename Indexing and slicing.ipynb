# %% [markdown]
# ### 6. Indexing,slicing and modification

# %%
import numpy as np

# %%
sweets = np.array([['pootharekulu','jalebi','khaja','laddu'],
                   ['rasogulla','Modakam','jangari','gulab jamun']])

# %%
sweets[1,2]
# Out:
# 'jangari'

# %%
sweets[1,:]
# Out:
# array(['rasogulla', 'Modakam', 'jangari', 'gulab jamun'], dtype='<U12')

# %%
sweets[:]
# Out:
# array(['rasogulla', 'Modakam', 'jangari', 'gulab jamun'], dtype='<U12')
